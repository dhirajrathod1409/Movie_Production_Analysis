# %%
from bs4 import BeautifulSoup as beut
import pandas as pd
import numpy as np
import re
import requests

# %% [markdown]
# https://www.imdb.com/list/ls050782187/?sort=list_order%2Casc
# https://www.imdb.com/list/ls050782187/?sort=list_order%2Casc&page=2

# %%
res ="https://www.imdb.com/list/ls050782187/?sort=list_order%2Casc"
request_header = {'Content-Type': 'text/html; charset=UTF-8','User-Agent': 'Chrome/101.0.0.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0','Accept-Encoding': 'gzip, deflate, br'}

page = requests.get(res,headers =request_header)
#page.text

# %%
soup=beut(page.text,'html.parser')

# %%
movie_name=[]
Year=[]
Duration=[]
Metascore=[]
Rating=[]
votes=[]
description=[]
director=[]
actors=[]

# %%
for i in soup.find_all('section',class_='ipc-page-section ipc-page-section--base ipc-page-section--sp-pageMargin list_page_mc_parent'):
    movie_name.append(re.findall('\\d+\\.\\s(.*?)\\d+h',i.text))
    Year.append(re.findall('(\\d+)\\d+h',i.text))
    Duration.append(re.findall('\\dh.*?m',i.text))
    Metascore.append(re.findall('(\\d+)Metascore',i.text))
    Rating.append(re.findall('Metascore(.*?)\\s',i.text))
    votes.append(re.findall('\\((.*?)\\)',i.text))
    description.append(re.findall('watched(.*?)\\.Director',i.text))
    director.append(re.findall('Director(.*?)Stars',i.text))
    actors.append(re.findall('Stars(.*?)\\d',i.text))

# %%
Name=[]
MOVIE_NAME=np.array(movie_name)
for i in MOVIE_NAME.flatten():
    Name.append(i)

# %%
print(Name,len(Name))
# Out:
# ['The Godfather', 'The Silence of the Lambs', 'Star Wars: Episode V - The Empire Strikes Back', 'The Shawshank Redemption', 'The Shining', 'Casablanca', "One Flew Over the Cuckoo's Nest", 'Raiders of the Lost Ark', 'The Lord of the Rings: The Return of the King', 'Star Wars: Episode IV - A New Hope', 'The Dark Knight', 'The Godfather: Part II', 'Alien ', "Schindler's List", 'Inception', 'The Lord of the Rings: The Fellowship of the Ring', 'Alien', 'Some Like It Hot', 'Blade Runner', 'Se7en', 'Apocalypse Now', '12 Angry Men', 'The Lord of the Rings: The Two Towers', 'Terminator 2: Judgment Day', 'Star Wars: Episode VI - Return of the Jedi'] 25

# %%
Year_of_Release=[]
data=np.array(Year)
for i in data.flatten():
    Year_of_Release.append(i)

# %%
print(Year_of_Release,len(Year_of_Release))
# Out:
# ['1972', '1991', '1980', '1994', '1980', '1942', '1975', '1981', '2003', '1977', '2008', '1974', '21986', '1993', '2010', '2001', '1979', '1959', '1982', '1995', '1979', '1957', '2002', '1991', '1983'] 25

# %%
Time_duration=[]
data2=np.array(Duration)
for i in data2.flatten():
    Time_duration.append(i)

# %%
print(Time_duration,len(Time_duration))
# Out:
# ['2h 55m', '1h 58m', '2h 4m', '2h 22m', '2h 26m', '1h 42m', '2h 13m', '1h 55m', '3h 21m', '2h 1m', '2h 32m', '3h 22m', '2h 17m', '3h 15m', '2h 28m', '2h 58m', '1h 57m', '2h 1m', '1h 57m', '2h 7m', '2h 27m', '1h 36m', '2h 59m', '2h 17m', '2h 11m'] 25

# %%
Meta_Scores=[]
data2=np.array(Metascore)
for i in data2.flatten():
    Meta_Scores.append(i)

# %%
print(Meta_Scores,len(Meta_Scores))
# Out:
# ['100', '86', '82', '82', '68', '100', '84', '86', '94', '90', '84', '90', '84', '95', '74', '92', '89', '98', '84', '65', '94', '97', '87', '75', '58'] 25

# %%
Imdb_Rating=[]
data3=np.array(Rating)
for i in data3.flatten():
    Imdb_Rating.append(i)

# %%
print(Imdb_Rating,len(Imdb_Rating))
# Out:
# ['9.2', '8.6', '8.7', '9.3', '8.4', '8.5', '8.7', '8.4', '9.0', '8.6', '9.0', '9.0', '8.4', '9.0', '8.8', '8.9', '8.5', '8.2', '8.1', '8.6', '8.4', '9.0', '8.8', '8.6', '8.3'] 25

# %%
Imdb_votes=[]
data4=np.array(votes)
for i in data4.flatten():
    Imdb_votes.append(i)

# %%
print(Imdb_votes,len(Imdb_votes))
# Out:
# ['2.1M', '1.6M', '1.4M', '3M', '1.2M', '630K', '1.1M', '1.1M', '2.1M', '1.5M', '3M', '1.4M', '807K', '1.5M', '2.7M', '2.1M', '1M', '295K', '853K', '1.9M', '741K', '923K', '1.9M', '1.2M', '1.2M'] 25

# %%
Movie_description=[]
data5=np.array(description)
for i in data5.flatten():
    Movie_description.append(i)

# %%
print(Movie_description,len(Movie_description))
# Out:
# ['The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son', 'A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims', 'After the Empire overpowers the Rebel Alliance, Luke Skywalker begins training with Jedi Master Yoda, while Darth Vader and bounty hunter Boba Fett pursue his friends across the galaxy', 'A banker convicted of uxoricide forms a friendship over a quarter century with a hardened convict, while maintaining his innocence and trying to remain hopeful through simple compassion', 'A family heads to an isolated hotel for the winter, where a sinister presence influences the father into violence. At the same time, his psychic son sees horrifying forebodings from both the past and the future', 'A cynical expatriate American cafe owner struggles to decide whether or not to help his former lover and her fugitive hus
# ...

# %%
Movie_director=[]
data6=np.array(director)
for i in data6.flatten():
    Movie_director.append(i)

# %%
print(Movie_director,len(Movie_director))
# Out:
# ['Francis Ford Coppola', 'Jonathan Demme', 'Irvin Kershner', 'Frank Darabont', 'Stanley Kubrick', 'Michael Curtiz', 'Milos Forman', 'Steven Spielberg', 'Peter Jackson', 'George Lucas', 'Christopher Nolan', 'Francis Ford Coppola', 'James Cameron', 'Steven Spielberg', 'Christopher Nolan', 'Peter Jackson', 'Ridley Scott', 'Billy Wilder', 'Ridley Scott', 'David Fincher', 'Francis Ford Coppola', 'Sidney Lumet', 'Peter Jackson', 'James Cameron', 'Richard Marquand'] 25

# %%
Movie_actors=[]
data7=np.array(actors)
for i in data7.flatten():
    Movie_actors.append(i)

# %%
print(Movie_actors,len(Movie_actors))
# Out:
# ['Marlon BrandoAl PacinoJames Caan', 'Jodie FosterAnthony HopkinsScott Glenn', 'Mark HamillHarrison FordCarrie Fisher', 'Tim RobbinsMorgan FreemanBob Gunton', 'Jack NicholsonShelley DuvallDanny Lloyd', 'Humphrey BogartIngrid BergmanPaul Henreid', 'Jack NicholsonLouise FletcherMichael Berryman', 'Harrison FordKaren AllenPaul Freeman', 'Elijah WoodViggo MortensenIan McKellen', 'Mark HamillHarrison FordCarrie Fisher', 'Christian BaleHeath LedgerAaron Eckhart', 'Al PacinoRobert De NiroRobert Duvall', 'Sigourney WeaverMichael BiehnCarrie Henn', 'Liam NeesonRalph FiennesBen Kingsley', 'Leonardo DiCaprioJoseph Gordon-LevittElliot Page', 'Elijah WoodIan McKellenOrlando Bloom', 'Sigourney WeaverTom SkerrittJohn Hurt', 'Marilyn MonroeTony CurtisJack Lemmon', 'Harrison FordRutger HauerSean Young', 'Morgan FreemanBrad PittKevin Spacey', 'Martin SheenMarlon BrandoRobert Duvall', 'Henry FondaLee J. CobbMartin Balsam', 'Elijah WoodIan McKellenViggo Mortensen', 'Arnold SchwarzeneggerLinda HamiltonEd
# ...

# %%
Movie_Data = {'Movie_name':Name,'Year_Of_Release':Year_of_Release,'Time_duration':Time_duration,
              'Meta_score':Meta_Scores,'Imdb_Rating':Imdb_Rating,
              'Imdb_votes':Imdb_votes,'Director':Movie_director,
              'Actors':Movie_actors,'Movie_Description':Movie_description}
df=pd.DataFrame(Movie_Data)

# %%
df.head()
# Out:
#                                        Movie_name Year_Of_Release  \
# 0                                   The Godfather            1972
# 1                        The Silence of the Lambs            1991
# 2  Star Wars: Episode V - The Empire Strikes Back            1980
# 3                        The Shawshank Redemption            1994
# 4                                     The Shining            1980
#
#   Time_duration Meta_score Imdb_Rating Imdb_votes              Director  \
# 0        2h 55m        100         9.2       2.1M  Francis Ford Coppola
# 1        1h 58m         86         8.6       1.6M        Jonathan Demme
# 2         2h 4m         82         8.7       1.4M        Irvin Kershner
# 3        2h 22m         82         9.3         3M        Frank Darabont
# 4        2h 26m         68         8.4       1.2M       Stanley Kubrick
#
#                                     Actors  \
# 0         Marlon BrandoAl PacinoJames Caan
# 1   Jodie FosterAnthony HopkinsScott Glenn
# ...

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

url = "https://www.imdb.com/list/ls050782187/?sort=list_order,asc"

driver = webdriver.Chrome()
driver.get(url)

# Scroll to load all movies
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)  # Wait for loading
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# Extract all movies
Movie_name=[]
Year=[]
Time=[]
metascore=[]
Rating=[]
Imdb_votes=[]
Movie_description=[]
director=[]
actors=[]
genre=[]
soup = beut(driver.page_source, "html.parser")
for movie in soup.find_all("h3", class_="ipc-title__text"):
      Movie_name.append(movie.text)
for movie in soup.find_all("span", class_="sc-5179a348-7 idrYgr dli-title-metadata-item"):
    regex=re.findall('\\d{4}',movie.text)
    if regex:
        Year.append(regex[0])
    regex2=re.findall('\\dh\\s\\d+m|\\dh',movie.text)
    if regex2:
        Time.append(regex2[0])
    data = re.findall('m\\s(.*?)\\s\\d{4}|h\\s(.*?)\\s\\d{4}|m\\s(\\w+)',movie.text)
    if data:
        Type.append(data[0])

for movie in soup.find_all("span", class_="sc-ae9e80c5-0 gXcoKx metacritic-score-box"):
        metascore.append(movie.text)

for movie in soup.find_all('span',class_='ipc-rating-star--rating'):
    Rating.append(movie.text)

for movie in soup.find_all("span", class_="ipc-rating-star--voteCount"):
    regex=re.findall('\\((.*?)\\)',movie.text)
    if regex:
        Imdb_votes.append(regex[0])
for movie in soup.find_all("div", class_="ipc-html-content-inner-div"):
    Movie_description.append(movie.text)
for movie in soup.find_all('div',class_='sc-7746c29e-1 jtgnlK'):
    director.append(re.findall('Director(.*?)Stars',movie.text))
    actors.append(re.findall('Stars(.*)',movie.text))
driver.quit()

# %%
genre
# Out:
# []

# %%
Name=[]
for i in range(len(Movie_name)-3):
    Name.append(Movie_name[i])
print(Name,len(Name))
# Out:
# ['1. The Godfather', '2. The Silence of the Lambs', '3. Star Wars: Episode V - The Empire Strikes Back', '4. The Shawshank Redemption', '5. The Shining', '6. Casablanca', "7. One Flew Over the Cuckoo's Nest", '8. Raiders of the Lost Ark', '9. The Lord of the Rings: The Return of the King', '10. Star Wars: Episode IV - A New Hope', '11. The Dark Knight', '12. The Godfather Part II', '13. Aliens', "14. Schindler's List", '15. Inception', '16. The Lord of the Rings: The Fellowship of the Ring', '17. Alien', '18. Some Like It Hot', '19. Blade Runner', '20. Se7en', '21. Apocalypse Now', '22. 12 Angry Men', '23. The Lord of the Rings: The Two Towers', '24. Terminator 2: Judgment Day', '25. Star Wars: Episode VI - Return of the Jedi', '26. Die Hard', '27. Gone with the Wind', '28. Taxi Driver', '29. Pulp Fiction', '30. The Bridge on the River Kwai', '31. The Lion King', '32. North by Northwest', '33. Rear Window', '34. Léon: The Professional', '35. Back to the Future', '36. Citizen Kane', '
# ...

# %%
print(Year,len(Year))
# Out:
# ['1972', '1991', '1980', '1994', '1980', '1942', '1975', '1981', '2003', '1977', '2008', '1974', '1986', '1993', '2010', '2001', '1979', '1959', '1982', '1995', '1979', '1957', '2002', '1991', '1983', '1988', '1939', '1976', '1994', '1957', '1994', '1959', '1954', '1994', '1985', '1941', '1990', '2000', '1999', '1997', '1994', '1952', '1995', '1998', '1988', '2010', '1968', '2003', '1972', '1966', '2001', '1936', '2003', '1987', '2000', '1999', '2007', '2012', '2006', '2007', '2006', '2006', '2005', '1974', '2002', '1944', '1996', '2012', '2008', '1958', '1996', '2014', '1982', '1949', '1995', '1997', '2002', '1999', '2012', '2015', '2013', '2015', '2013', '1989', '2000', '2009', '2006', '2001', '2009', '1993', '2003', '1999', '1997', '1995', '1995', '1967', '2004', '1931', '1999', '2005', '1990', '1993', '1975', '1978', '1983', '1971', '1980', '1973', '1962', '1955', '2004', '1990', '2003', '2005', '2012', '1948', '1987', '1998', '1992', '1960', '1946', '2012', '2014', '1959', '1998
# ...

# %%
print(Time,len(Time))
# Out:
# ['2h 55m', '1h 58m', '2h 4m', '2h 22m', '2h 26m', '1h 42m', '2h 13m', '1h 55m', '3h 21m', '2h 1m', '2h 32m', '3h 22m', '2h 17m', '3h 15m', '2h 28m', '2h 58m', '1h 57m', '2h 1m', '1h 57m', '2h 7m', '2h 27m', '1h 36m', '2h 59m', '2h 17m', '2h 11m', '2h 12m', '3h 58m', '1h 54m', '2h 34m', '2h 41m', '1h 28m', '2h 16m', '1h 52m', '1h 50m', '1h 56m', '1h 59m', '2h 25m', '1h 53m', '2h 2m', '2h 19m', '2h 22m', '1h 43m', '2h 58m', '2h 49m', '2h 13m', '1h 58m', '2h 29m', '1h 51m', '2h 24m', '2h 58m', '2h 2m', '1h 27m', '1h 42m', '1h 56m', '1h 42m', '2h 19m', '2h 2m', '2h 45m', '1h 49m', '1h 51m', '2h 17m', '2h 10m', '2h 12m', '2h 10m', '2h 10m', '1h 40m', '1h 38m', '2h 7m', '2h', '2h 8m', '1h 33m', '2h 49m', '1h 49m', '1h 44m', '2h 9m', '1h 56m', '2h 30m', '3h 8m', '2h 44m', '2h 18m', '2h 41m', '2h', '2h 14m', '2h 7m', '1h 47m', '2h 33m', '2h 31m', '2h 15m', '1h 52m', '2h 1m', '2h 18m', '2h 37m', '2h 18m', '2h 50m', '1h 46m', '2h 7m', '1h 48m', '1h 27m', '2h 16m', '2h 4m', '1h 47m', '1h 58m', 
# ...

# %%
for i in range(len(metascore)):
    if i in [49,123,150]:
        metascore.insert(i,np.nan)

# %%
print(metascore,len(metascore))
# Out:
# ['100', '86', '82', '82', '68', '100', '84', '86', '94', '90', '84', '90', '84', '95', '74', '92', '89', '98', '84', '65', '94', '97', '87', '75', '58', '72', '97', '94', '95', '88', '88', '98', '100', '64', '87', '100', '92', '83', '84', '67', '82', '99', '68', '91', '65', '88', '84', '69', '90', nan, '70', '96', '91', '78', '71', '67', '92', '81', '84', '96', '89', '66', '62', '92', '79', '90', '88', '79', '84', '100', '83', '74', '57', '97', '75', '58', '85', '78', '78', '80', '66', '90', '96', '65', '69', '69', '85', '72', '81', '89', '84', '85', '91', '76', '76', '92', '89', '99', '73', '74', '75', '73', '91', '90', '65', '77', '78', '58', '100', '72', '79', '72', '63', '70', '81', '98', '79', '90', '81', '94', '86', '95', '90', nan, '81', '93', '89', '82', '70', '73', '88', '75', '83', '84', '58', '83', '67', '86', '79', '61', '83', '90', '73', '87', '82', '100', '86', '82', '87', '86', nan, '83', '90', '79', '74', '87', '71', '62', '80', '92', '78', '76', '60', '62', '79', '79
# ...

# %%
print(Rating,len(Rating))
# Out:
# ['9.2', '8.6', '8.7', '9.3', '8.4', '8.5', '8.7', '8.4', '9.0', '8.6', '9.0', '9.0', '8.4', '9.0', '8.8', '8.9', '8.5', '8.2', '8.1', '8.6', '8.4', '9.0', '8.8', '8.6', '8.3', '8.2', '8.2', '8.2', '8.9', '8.1', '8.5', '8.3', '8.5', '8.5', '8.5', '8.3', '8.7', '8.4', '8.3', '7.7', '8.8', '8.3', '8.3', '8.6', '8.0', '8.0', '8.3', '8.2', '7.2', '8.8', '8.3', '8.5', '7.7', '8.2', '8.3', '8.8', '8.2', '8.5', '7.9', '8.1', '8.4', '8.5', '8.1', '8.1', '8.6', '7.8', '8.1', '7.9', '8.0', '8.2', '8.1', '8.7', '8.2', '8.1', '8.0', '8.6', '8.5', '8.0', '8.4', '7.8', '7.8', '8.1', '8.1', '8.2', '7.7', '8.4', '8.5', '8.2', '7.9', '7.5', '7.9', '7.8', '8.2', '8.3', '8.5', '8.0', '8.3', '8.5', '8.7', '8.0', '7.8', '7.7', '8.2', '8.1', '8.3', '8.2', '8.2', '8.0', '8.3', '7.8', '8.1', '8.0', '8.1', '8.2', '7.8', '8.2', '7.8', '8.2', '8.3', '8.3', '7.9', '7.9', '6.7', '8.1', '7.7', '8.0', '7.6', '8.2', '8.1', '8.1', '7.9', '8.0', '8.1', '8.1', '7.8', '8.0', '8.5', '7.5', '7.7', '8.6', '7.9', '7.7', '8.
# ...

# %%
print(Imdb_votes,len(Imdb_votes))
# Out:
# ['2.1M', '1.6M', '1.4M', '3M', '1.2M', '630K', '1.1M', '1.1M', '2.1M', '1.5M', '3M', '1.4M', '807K', '1.5M', '2.7M', '2.1M', '1M', '295K', '853K', '1.9M', '741K', '923K', '1.9M', '1.2M', '1.2M', '989K', '346K', '977K', '2.3M', '241K', '1.2M', '360K', '545K', '1.3M', '1.4M', '480K', '1.3M', '1.4M', '1.2M', '328K', '2.4M', '272K', '1.1M', '1.6M', '564K', '721K', '752K', '1.2M', '12K', '851K', '818K', '272K', '510K', '821K', '937K', '2.5M', '1.1M', '1.8M', '547K', '883K', '427K', '1.5M', '1.2M', '364K', '836K', '40K', '755K', '684K', '895K', '444K', '748K', '2.3M', '497K', '189K', '663K', '777K', '966K', '338K', '1.9M', '998K', '731K', '1.2M', '764K', '837K', '341K', '1.7M', '1.5M', '1M', '735K', '98K', '503K', '186K', '640K', '756K', '1.2M', '194K', '1.1M', '207K', '2.2M', '807K', '249K', '262K', '587K', '375K', '963K', '910K', '272K', '142K', '329K', '50K', '383K', '301K', '1.3M', '1.6M', '750K', '137K', '343K', '1.3M', '1.1M', '209K', '93K', '108K', '3.1K', '263K', '77K', '129K', '18
# ...

# %%
Description=[]

# %%
for i in range(1,len(Movie_description)):
    Description.append(Movie_description[i])

# %%
print(Description,len(Description))
# Out:
# ['The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.', 'A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.', 'After the Empire overpowers the Rebel Alliance, Luke Skywalker begins training with Jedi Master Yoda, while Darth Vader and bounty hunter Boba Fett pursue his friends across the galaxy.', 'A banker convicted of uxoricide forms a friendship over a quarter century with a hardened convict, while maintaining his innocence and trying to remain hopeful through simple compassion.', 'A family heads to an isolated hotel for the winter, where a sinister presence influences the father into violence. At the same time, his psychic son sees horrifying forebodings from both the past and the future.', 'A cynical expatriate American cafe owner struggles to decide whether or not to help his former lover and her fugitiv
# ...

# %%
Movie_director=[]
data6=np.array(director)
for i in data6.flatten():
    Movie_director.append(i)

# %%
print(Movie_director,len(Movie_director))
# Out:
# ['Francis Ford Coppola', 'Jonathan Demme', 'Irvin Kershner', 'Frank Darabont', 'Stanley Kubrick', 'Michael Curtiz', 'Milos Forman', 'Steven Spielberg', 'Peter Jackson', 'George Lucas', 'Christopher Nolan', 'Francis Ford Coppola', 'James Cameron', 'Steven Spielberg', 'Christopher Nolan', 'Peter Jackson', 'Ridley Scott', 'Billy Wilder', 'Ridley Scott', 'David Fincher', 'Francis Ford Coppola', 'Sidney Lumet', 'Peter Jackson', 'James Cameron', 'Richard Marquand', 'John McTiernan', 'Victor Fleming', 'Martin Scorsese', 'Quentin Tarantino', 'David Lean', 'sRoger AllersRob Minkoff', 'Alfred Hitchcock', 'Alfred Hitchcock', 'Luc Besson', 'Robert Zemeckis', 'Orson Welles', 'Martin Scorsese', 'Christopher Nolan', 'Sam Mendes', 'James L. Brooks', 'Robert Zemeckis', 'sStanley DonenGene Kelly', 'Mel Gibson', 'Steven Spielberg', 'Barry Levinson', 'Tom Hooper', 'Stanley Kubrick', 'Quentin Tarantino', 'Billy Wilder', 'Sergio Leone', 'Jean-Pierre Jeunet', 'Charles Chaplin', 'Sofia Coppola', 'Stanley Ku
# ...

# %%
Movie_actors=[]
data7=np.array(actors)
for i in data7.flatten():
    Movie_actors.append(i)

# %%
print(Movie_actors,len(Movie_actors))
# Out:
# ['Marlon BrandoAl PacinoJames Caan', 'Jodie FosterAnthony HopkinsScott Glenn', 'Mark HamillHarrison FordCarrie Fisher', 'Tim RobbinsMorgan FreemanBob Gunton', 'Jack NicholsonShelley DuvallDanny Lloyd', 'Humphrey BogartIngrid BergmanPaul Henreid', 'Jack NicholsonLouise FletcherMichael Berryman', 'Harrison FordKaren AllenPaul Freeman', 'Elijah WoodViggo MortensenIan McKellen', 'Mark HamillHarrison FordCarrie Fisher', 'Christian BaleHeath LedgerAaron Eckhart', 'Al PacinoRobert De NiroRobert Duvall', 'Sigourney WeaverMichael BiehnCarrie Henn', 'Liam NeesonRalph FiennesBen Kingsley', 'Leonardo DiCaprioJoseph Gordon-LevittElliot Page', 'Elijah WoodIan McKellenOrlando Bloom', 'Sigourney WeaverTom SkerrittJohn Hurt', 'Marilyn MonroeTony CurtisJack Lemmon', 'Harrison FordRutger HauerSean Young', 'Morgan FreemanBrad PittKevin Spacey', 'Martin SheenMarlon BrandoRobert Duvall', 'Henry FondaLee J. CobbMartin Balsam', 'Elijah WoodIan McKellenViggo Mortensen', 'Arnold SchwarzeneggerLinda HamiltonEd
# ...

# %%
a=[]
for movie in soup.find_all('span',class_='sc-5179a348-7 idrYgr dli-title-metadata-item'):
    a.append(movie.text)

# %%
print(a,end='')
print(len(a))
# Out:
# ['1972', '2h 55m', 'R', '1991', '1h 58m', 'R', '1980', '2h 4m', 'PG', '1994', '2h 22m', 'R', '1980', '2h 26m', 'R', '1942', '1h 42m', 'PG', '1975', '2h 13m', 'R', '1981', '1h 55m', 'PG', '2003', '3h 21m', 'PG-13', '1977', '2h 1m', 'PG', '2008', '2h 32m', 'PG-13', '1974', '3h 22m', 'R', '1986', '2h 17m', 'R', '1993', '3h 15m', 'R', '2010', '2h 28m', 'PG-13', '2001', '2h 58m', 'PG-13', '1979', '1h 57m', 'R', '1959', '2h 1m', 'Approved', '1982', '1h 57m', 'R', '1995', '2h 7m', 'R', '1979', '2h 27m', 'R', '1957', '1h 36m', 'Approved', '2002', '2h 59m', 'PG-13', '1991', '2h 17m', 'R', '1983', '2h 11m', 'PG', '1988', '2h 12m', 'R', '1939', '3h 58m', 'G', '1976', '1h 54m', 'R', '1994', '2h 34m', 'R', '1957', '2h 41m', 'PG', '1994', '1h 28m', 'G', '1959', '2h 16m', 'Approved', '1954', '1h 52m', 'PG', '1994', '1h 50m', 'R', '1985', '1h 56m', 'PG', '1941', '1h 59m', 'PG', '1990', '2h 25m', 'R', '2000', '1h 53m', 'R', '1999', '2h 2m', 'R', '1997', '2h 19m', 'PG-13', '1994', '2h 22m', 'PG-13', '
# ...

# %%
a ="'1972', '2h 55m', 'R', '1991', '1h 58m', 'R', '1980', '2h 4m', 'PG', '1994', '2h 22m', 'R', '1980', '2h 26m', 'R', '1942', '1h 42m', 'PG', '1975', '2h 13m', 'R', '1981', '1h 55m', 'PG', '2003', '3h 21m', 'PG-13', '1977', '2h 1m', 'PG', '2008', '2h 32m', 'PG-13', '1974', '3h 22m', 'R', '1986', '2h 17m', 'R', '1993', '3h 15m', 'R', '2010', '2h 28m', 'PG-13', '2001', '2h 58m', 'PG-13', '1979', '1h 57m', 'R', '1959', '2h 1m', 'Approved', '1982', '1h 57m', 'R', '1995', '2h 7m', 'R', '1979', '2h 27m', 'R', '1957', '1h 36m', 'Approved', '2002', '2h 59m', 'PG-13', '1991', '2h 17m', 'R', '1983', '2h 11m', 'PG', '1988', '2h 12m', 'R', '1939', '3h 58m', 'G', '1976', '1h 54m', 'R', '1994', '2h 34m', 'R', '1957', '2h 41m', 'PG', '1994', '1h 28m', 'G', '1959', '2h 16m', 'Approved', '1954', '1h 52m', 'PG', '1994', '1h 50m', 'R', '1985', '1h 56m', 'PG', '1941', '1h 59m', 'PG', '1990', '2h 25m', 'R', '2000', '1h 53m', 'R', '1999', '2h 2m', 'R', '1997', '2h 19m', 'PG-13', '1994', '2h 22m', 'PG-13', '1952', '1h 43m', 'G', '1995', '2h 58m', 'R', '1998', '2h 49m', 'R', '1988', '2h 13m', 'R', '2010', '1h 58m', 'R', '1968', '2h 29m', 'G', '2003', '1h 51m', 'R', '1972', '2h 24m', 'R', '1966', '2h 58m', 'R', '2001', '2h 2m', 'R', '1936', '1h 27m', 'G', '2003', '1h 42m', 'R', '1987', '1h 56m', 'R', '2000', '1h 42m', 'NC-17', '1999', '2h 19m', 'R', '2007', '2h 2m', 'R', '2012', '2h 45m', 'R', '2006', '1h 49m', 'R', '2007', '1h 51m', 'G', '2006', '2h 17m', 'R', '2006', '2h 10m', 'PG-13', '2005', '2h 12m', 'R', '1974', '2h 10m', 'R', '2002', '2h 10m', 'R', '1944', '1h 40m', 'Approved', '1996', '1h 38m', 'R', '2012', '2h 7m', 'PG', '2008', '2h', 'R', '1958', '2h 8m', 'PG', '1996', '1h 33m', 'R', '2014', '2h 49m', 'PG-13', '1982', '1h 49m', 'R', '1949', '1h 44m', 'Approved', '1995', '2h 9m', 'R', '1997', '1h 56m', 'PG-13', '2002', '2h 30m', 'R', '1999', '3h 8m', 'R', '2012', '2h 44m', 'PG-13', '2015', '2h 18m', 'PG-13', '2013', '2h 41m', 'PG-13', '2015', '2h', 'R', '2013', '2h 14m', 'R', '1989', '2h 7m', 'PG-13', '2000', '1h 47m', 'PG-13', '2009', '2h 33m', 'R', '2006', '2h 31m', 'R', '2001', '2h 15m', 'PG-13', '2009', '1h 52m', 'R', '1993', '2h 1m', 'R', '2003', '2h 18m', 'R', '1999', '2h 37m', 'R', '1997', '2h 18m', 'R', '1995', '2h 50m', 'R', '1995', '1h 46m', 'R', '1967', '2h 7m', 'Approved', '2004', '1h 48m', 'R', '1931', '1h 27m', 'G', '1999', '2h 16m', 'R', '2005', '2h 4m', 'R', '1990', '1h 47m', 'R', '1993', '1h 58m', 'PG-13', '1975', '1h 31m', 'PG', '1978', '3h 3m', 'R', '1983', '2h 50m', 'R', '1971', '2h 16m', 'R', '1980', '2h 4m', 'PG', '1973', '2h 31m', 'R', '1962', '3h 47m', 'PG', '1955', '1h 58m', 'PG', '2004', '2h 1m', 'PG-13', '1990', '3h 1m', 'PG-13', '2003', '2h 23m', 'PG-13', '2005', '2h 20m', 'PG-13', '2012', '2h 23m', 'PG-13', '1948', '2h 6m', 'Approved', '1987', '1h 59m', 'R', '1998', '1h 43m', 'PG', '1992', '1h 39m', 'R', '1960', '2h 5m', 'Approved', '1946', '1h 54m', 'Approved', '2012', '2h 7m', 'PG-13', '2014', '1h 42m', 'Not Rated', '1959', '3h 32m', 'G', '1998', '2h 14m', 'NC-17', '1963', '2h 18m', 'Not Rated', '1991', '2h 10m', 'R', '2004', '2h 36m', 'R', '1976', '2h', 'PG', '2008', '1h 56m', 'R', '1951', '1h 41m', 'PG', '1966', '2h 11m', 'Approved', '1973', '2h 2m', 'R', '1984', '1h 47m', 'R', '2012', '2h 49m', 'PG-13', '2004', '2h 17m', 'R', '2000', '2h 35m', 'R', '2000', '2h 27m', 'R', '2007', '2h 37m', 'R', '1999', '3h 9m', 'R', '2009', '2h 42m', 'PG-13', '1978', '1h 31m', 'R', '1995', '2h 58m', 'R', '1975', '2h 4m', 'PG', '1968', '2h 46m', 'PG-13', '1946', '1h 42m', 'Approved', '1963', '2h 52m', 'Approved', '1993', '1h 16m', 'PG', '1964', '1h 50m', 'Approved', '2007', '2h 7m', 'R', '2012', '2h', 'R', '2008', '2h 8m', 'R', '1999', '1h 53m', 'R', '2010', '1h 48m', 'R', '2001', '1h 44m', 'PG-13', '2005', '2h 14m', 'R', '2004', '2h', 'R', '1997', '2h 34m', 'R', '2006', '2h 24m', 'PG-13', '1986', '2h', 'R', '1998', '2h 50m', 'R', '2013', '2h 26m', 'PG-13', '1990', '2h 42m', 'R', '1998', '1h 59m', 'R', '1989', '2h 8m', 'PG', '2007', '1h 44m', 'PG-13', '2002', '1h 52m', 'R', '2009', '2h 32m', 'R', '1981', '2h 29m', '2004', '2h 7m', 'R', '1992', '2h 36m', 'R', '1972', '1h 49m', 'R', '2008', '1h 30m', 'PG-13', '1989', '1h 48m', 'PG', '1957', '1h 21m', 'Approved', '1993', '2h 10m', 'PG-13', '2010', '2h 18m', 'R', '1998', '1h 57m', 'R', '1972', '2h 9m', 'NC-17', '1999', '2h 19m', 'R', '1982', '1h 33m', 'R', '2010', '2h 8m', 'PG-13', '2004', '2h 12m', 'PG-13', '2001', '1h 56m', 'R', '2008', '1h 49m', 'R', '2009', '1h 43m', 'R', '2002', '1h 59m', 'PG-13', '1978', '1h 37m', 'R', '2007', '2h 38m', 'R', '2000', '1h 50m', 'R', '2006', '1h 41m', 'R', '2014', '2h 24m', 'R', '2012', '2h 22m', 'PG-13', '1960', '1h 49m', 'R', '1982', '1h 55m', 'PG', '1979', '1h 45m', 'PG', '2003', '1h 53m', 'PG-13', '2005', '1h 43m', 'R', '2008', '1h 38m', 'G', '1971', '1h 42m', 'R', '2005', '2h 20m', 'PG-13', '1986', '1h 29m', 'R', '1984', '1h 31m', 'R', '2003', '1h 40m', 'G', '1994', '1h 35m', 'R', '1997', '2h 6m', 'PG-13', '1999', '1h 47m', 'PG-13', '2000', '2h 34m', 'R', '1993', '2h 7m', 'PG-13', '1993', '2h 24m', 'R', '1992', '1h 21m', 'R', '1988', '1h 48m', 'R', '1997', '2h 6m', 'R', '1958', '1h 48m', 'Approved', '1990', '1h 53m', 'R', '2000', '2h', 'PG-13', '1998', '1h 29m', 'Not Rated', '2003', '2h 4m', 'R', '1991', '2h 8m', 'R', '2006', '2h 9m', 'R', '2014', '1h 42m', 'R', '1993', '1h 41m', 'PG', '1991', '3h 9m', 'R', '2001', '2h 24m', 'R', '2004', '1h 46m', 'R', '2009', '2h 42m', 'R', '2013', '1h 54m', 'R', '2002', '1h 49m', 'R', '2004', '2h 6m', 'PG-13', '2002', '2h 21m', 'PG-13', '1999', '1h 58m', 'R', '1993', '2h 8m', 'R', '2001', '2h 6m', 'R', '2008', '2h 21m', 'R', '2008', '2h 4m', 'R', '1987', '1h 47m', 'R', '2001', '1h 49m', 'R', '2008', '1h 51m', 'R', '1986', '2h', 'R', '2000', '1h 53m', 'R', '2008', '2h 46m', 'PG-13', '1996', '2h 42m', 'R', '1939', '1h 42m', 'G', '1940', '1h 52m', 'Approved', '1959', '2h 21m', 'Approved', '2004', '1h 37m', 'PG-13', '2005', '2h 2m', 'R', '1998', '1h 47m', 'R', '2003', '2h 5m', 'PG-13', '1992', '1h 44m', 'R'"
b=re.findall("'([A-Za-z-]+)'|'([A-Za-z]+\-\d+)|'([a-zA-Z]+\s[a-zA-Z]+)'",a)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\-'
# <>:2: SyntaxWarning: invalid escape sequence '\-'
# C:\Users\Dhiraj Rathod\AppData\Local\Temp\ipykernel_10916\2448513267.py:2: SyntaxWarning: invalid escape sequence '\-'
#   b=re.findall("'([A-Za-z-]+)'|'([A-Za-z]+\-\d+)|'([a-zA-Z]+\s[a-zA-Z]+)'",a)

# %%
print(b,len(b))
# Out:
# [('R', '', ''), ('R', '', ''), ('PG', '', ''), ('R', '', ''), ('R', '', ''), ('PG', '', ''), ('R', '', ''), ('PG', '', ''), ('', 'PG-13', ''), ('PG', '', ''), ('', 'PG-13', ''), ('R', '', ''), ('R', '', ''), ('R', '', ''), ('', 'PG-13', ''), ('', 'PG-13', ''), ('R', '', ''), ('Approved', '', ''), ('R', '', ''), ('R', '', ''), ('R', '', ''), ('Approved', '', ''), ('', 'PG-13', ''), ('R', '', ''), ('PG', '', ''), ('R', '', ''), ('G', '', ''), ('R', '', ''), ('R', '', ''), ('PG', '', ''), ('G', '', ''), ('Approved', '', ''), ('PG', '', ''), ('R', '', ''), ('PG', '', ''), ('PG', '', ''), ('R', '', ''), ('R', '', ''), ('R', '', ''), ('', 'PG-13', ''), ('', 'PG-13', ''), ('G', '', ''), ('R', '', ''), ('R', '', ''), ('R', '', ''), ('R', '', ''), ('G', '', ''), ('R', '', ''), ('R', '', ''), ('R', '', ''), ('R', '', ''), ('G', '', ''), ('R', '', ''), ('R', '', ''), ('', 'NC-17', ''), ('R', '', ''), ('R', '', ''), ('R', '', ''), ('R', '', ''), ('G', '', ''), ('R', '', ''), ('', 'PG-13', ''), (
# ...

# %%
movie_type = []

# %%
for i in b:
    for j in i:
        if j=='':
            pass
        else:
            movie_type.append(j)

# %%
print(movie_type,len(movie_type))
# Out:
# ['R', 'R', 'PG', 'R', 'R', 'PG', 'R', 'PG', 'PG-13', 'PG', 'PG-13', 'R', 'R', 'R', 'PG-13', 'PG-13', 'R', 'Approved', 'R', 'R', 'R', 'Approved', 'PG-13', 'R', 'PG', 'R', 'G', 'R', 'R', 'PG', 'G', 'Approved', 'PG', 'R', 'PG', 'PG', 'R', 'R', 'R', 'PG-13', 'PG-13', 'G', 'R', 'R', 'R', 'R', 'G', 'R', 'R', 'R', 'R', 'G', 'R', 'R', 'NC-17', 'R', 'R', 'R', 'R', 'G', 'R', 'PG-13', 'R', 'R', 'R', 'Approved', 'R', 'PG', 'R', 'PG', 'R', 'PG-13', 'R', 'Approved', 'R', 'PG-13', 'R', 'R', 'PG-13', 'PG-13', 'PG-13', 'R', 'R', 'PG-13', 'PG-13', 'R', 'R', 'PG-13', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'Approved', 'R', 'G', 'R', 'R', 'R', 'PG-13', 'PG', 'R', 'R', 'R', 'PG', 'R', 'PG', 'PG', 'PG-13', 'PG-13', 'PG-13', 'PG-13', 'PG-13', 'Approved', 'R', 'PG', 'R', 'Approved', 'Approved', 'PG-13', 'Not Rated', 'G', 'NC-17', 'Not Rated', 'R', 'R', 'PG', 'R', 'PG', 'Approved', 'R', 'R', 'PG-13', 'R', 'R', 'R', 'R', 'R', 'PG-13', 'R', 'R', 'PG', 'PG-13', 'Approved', 'Approved', 'PG', 'Approved', 'R', 'R', 'R'
# ...

# %%
for i in range(len(movie_type)):
    if i == 169:
        movie_type.insert(i,np.nan)

# %%
print(movie_type,len(movie_type))
# Out:
# ['R', 'R', 'PG', 'R', 'R', 'PG', 'R', 'PG', 'PG-13', 'PG', 'PG-13', 'R', 'R', 'R', 'PG-13', 'PG-13', 'R', 'Approved', 'R', 'R', 'R', 'Approved', 'PG-13', 'R', 'PG', 'R', 'G', 'R', 'R', 'PG', 'G', 'Approved', 'PG', 'R', 'PG', 'PG', 'R', 'R', 'R', 'PG-13', 'PG-13', 'G', 'R', 'R', 'R', 'R', 'G', 'R', 'R', 'R', 'R', 'G', 'R', 'R', 'NC-17', 'R', 'R', 'R', 'R', 'G', 'R', 'PG-13', 'R', 'R', 'R', 'Approved', 'R', 'PG', 'R', 'PG', 'R', 'PG-13', 'R', 'Approved', 'R', 'PG-13', 'R', 'R', 'PG-13', 'PG-13', 'PG-13', 'R', 'R', 'PG-13', 'PG-13', 'R', 'R', 'PG-13', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'Approved', 'R', 'G', 'R', 'R', 'R', 'PG-13', 'PG', 'R', 'R', 'R', 'PG', 'R', 'PG', 'PG', 'PG-13', 'PG-13', 'PG-13', 'PG-13', 'PG-13', 'Approved', 'R', 'PG', 'R', 'Approved', 'Approved', 'PG-13', 'Not Rated', 'G', 'NC-17', 'Not Rated', 'R', 'R', 'PG', 'R', 'PG', 'Approved', 'R', 'R', 'PG-13', 'R', 'R', 'R', 'R', 'R', 'PG-13', 'R', 'R', 'PG', 'PG-13', 'Approved', 'Approved', 'PG', 'Approved', 'R', 'R', 'R'
# ...

# %%
Dict = {'Movie_name':Name,'Release_Year':Year,
       'Time_duration':Time,'Imdb_Rating':Rating,
       'Imdb_votes':Imdb_votes,'Meta_score':metascore,'movie_type':movie_type,'Director':Movie_director,'Actors':Movie_actors,'Movie_Description':Description}
df=pd.DataFrame(Dict)

# %%
df.head()
# Out:
#                                           Movie_name Release_Year  \
# 0                                   1. The Godfather         1972
# 1                        2. The Silence of the Lambs         1991
# 2  3. Star Wars: Episode V - The Empire Strikes Back         1980
# 3                        4. The Shawshank Redemption         1994
# 4                                     5. The Shining         1980
#
#   Time_duration Imdb_Rating Imdb_votes Meta_score movie_type  \
# 0        2h 55m         9.2       2.1M        100          R
# 1        1h 58m         8.6       1.6M         86          R
# 2         2h 4m         8.7       1.4M         82         PG
# 3        2h 22m         9.3         3M         82          R
# 4        2h 26m         8.4       1.2M         68          R
#
#                Director                                   Actors  \
# 0  Francis Ford Coppola         Marlon BrandoAl PacinoJames Caan
# 1        Jonathan Demme   Jodie FosterAnthony HopkinsScott Glenn
# ...

# %% [markdown]
# df.info()

# %%
df['Release_Year']=df.Release_Year.apply(lambda x : int(x))

# %%
df['Imdb_Rating'] = df.Imdb_Rating.apply(lambda x : float(x))

# %%
df['Movie_name']=df['Movie_name'].apply(lambda x : x.split('.')[1])

# %%
votes=[]
for i in df['Imdb_votes']:
    if 'M' in i:
        votes.append(float(i.replace('M',''))*1000000)
    elif 'K' in i:
        votes.append(float(i.replace('K',''))*1000)
#print(votes,len(votes))

# %%
df['Imdb_votes']=votes

# %%
df['Meta_score']=df['Meta_score'].apply(lambda x : float(x))

# %%
df.fillna({'Meta_score':round(df.Meta_score.mean(),2)},inplace=True)

# %%
df
# Out:
#                                           Movie_name  Release_Year  \
# 0                                      The Godfather          1972
# 1                           The Silence of the Lambs          1991
# 2     Star Wars: Episode V - The Empire Strikes Back          1980
# 3                           The Shawshank Redemption          1994
# 4                                        The Shining          1980
# ..                                               ...           ...
# 245                                       The Chorus          2004
# 246                                      Lord of War          2005
# 247              Lock, Stock and Two Smoking Barrels          1998
# 248                                         Big Fish          2003
# 249                                       Dead Alive          1992
#
#     Time_duration  Imdb_Rating  Imdb_votes  Meta_score movie_type  \
# 0          2h 55m          9.2   2100000.0       100.0          R
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Movie_name         250 non-null    object
#  1   Release_Year       250 non-null    int64
#  2   Time_duration      250 non-null    object
#  3   Imdb_Rating        250 non-null    float64
#  4   Imdb_votes         250 non-null    float64
#  5   Meta_score         250 non-null    float64
#  6   movie_type         249 non-null    object
#  7   Director           250 non-null    object
#  8   Actors             250 non-null    object
#  9   Movie_Description  250 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 19.7+ KB

# %%
df.head()
# Out:
#                                         Movie_name  Release_Year  \
# 0                                    The Godfather          1972
# 1                         The Silence of the Lambs          1991
# 2   Star Wars: Episode V - The Empire Strikes Back          1980
# 3                         The Shawshank Redemption          1994
# 4                                      The Shining          1980
#
#   Time_duration  Imdb_Rating  Imdb_votes  Meta_score movie_type  \
# 0        2h 55m          9.2   2100000.0       100.0          R
# 1        1h 58m          8.6   1600000.0        86.0          R
# 2         2h 4m          8.7   1400000.0        82.0         PG
# 3        2h 22m          9.3   3000000.0        82.0          R
# 4        2h 26m          8.4   1200000.0        68.0          R
#
#                Director                                   Actors  \
# 0  Francis Ford Coppola         Marlon BrandoAl PacinoJames Caan
# ...

# %%
#df.to_csv('df1.csv',index=False)
